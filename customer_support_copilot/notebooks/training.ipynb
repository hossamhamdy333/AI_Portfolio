# %%
import os
os.chdir("/content")
# !git clone https://github.com/hossamhamdy333/AI_Portfolio.git
os.chdir("/content/AI_Portfolio")
# Out:
# fatal: destination path 'AI_Portfolio' already exists and is not an empty directory.

# %%
# !pip install unsloth
# Out:
# Requirement already satisfied: unsloth in /usr/local/lib/python3.12/dist-packages (2026.8.7)
# Requirement already satisfied: unsloth_zoo>=2026.8.5 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2026.8.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.47.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth) (26.2)
# Requirement already satisfied: torch<2.12.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: tyro in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.0.15)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.29.6)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.0.35)
# Requirement already satisfied: bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.50.0)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.2.2)
# Requirement already satisfied: datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.3.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.14.0)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.19.1)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.23.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.39.0)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3 in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.5.0)
# Requirement already satisfied: trl!=0.19.0,<=0.24.0,>=0.18.2 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.24.0)
# Requirement already satisfied: typer>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.26.8)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.13.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from unsloth) (6.0.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.6.0)
# Requirement already satisfied: structlog>=24.1.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (26.1.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (8.4.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from unsloth) (13.9.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.29.7)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (25.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.8.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.5.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.12.0,>=2.4.0->unsloth) (3.4.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.12.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth) (0.22.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12.0->unsloth) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12.0->unsloth) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->unsloth) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->unsloth) (2.20.0)
# Requirement already satisfied: torchao>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.8.5->unsloth) (0.18.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.8.5->unsloth) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.8.5->unsloth) (11.3.0)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.8.5->unsloth) (0.21.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth) (0.4.2)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (0.18.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (4.5.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch<2.12.0,>=2.4.0->unsloth) (1.5.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->unsloth) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.12.0,>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->unsloth) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.12.0,>=2.4.0->unsloth) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.17.0)

# %%
os.chdir("/content/AI_Portfolio/customer_support_copilot")
import os
from unsloth import FastLanguageModel
from datasets import load_dataset
from trl import SFTTrainer, SFTConfig

def train():
    os.makedirs("outputs", exist_ok=True)

    # Explicitly load model onto GPU 0
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name="unsloth/llama-3-8b-bnb-4bit",
        max_seq_length=512,
        load_in_4bit=True,
        device_map="cuda:0",  # Force single-GPU loading
    )

    # Apply LoRA Adapters
    model = FastLanguageModel.get_peft_model(
        model,
        r=16,
        target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
        lora_alpha=16,
        lora_dropout=0,
        bias="none",
        use_gradient_checkpointing="unsloth",
    )

    # Load Data & Train
    dataset = load_dataset("json", data_files="data/train.jsonl", split="train")

    trainer = SFTTrainer(
        model=model,
        tokenizer=tokenizer,
        train_dataset=dataset,
        dataset_text_field="text",
        max_seq_length=512,
        args=SFTConfig(
            per_device_train_batch_size=2,
            gradient_accumulation_steps=4,
            num_train_epochs=2,
            learning_rate=2e-4,
            optim="adamw_8bit",
            output_dir="outputs/support_lora",
            dataset_text_field="text",
            max_seq_length=512,
        ),
    )

    trainer.train()
    model.save_pretrained("outputs/support_lora")
    tokenizer.save_pretrained("outputs/support_lora")
    print("Training Complete. LoRA weights saved!")

if __name__ == "__main__":
    train()
# Out:
# ==((====))==  Unsloth 2026.8.7: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Unsloth: Will load unsloth/llama-3-8b-bnb-4bit as a legacy tokenizer.
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/5000 [00:00<?, ? examples/s]
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 5,000 | Num Epochs = 2 | Total steps = 1,250
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
# Unsloth: Will smartly offload gradients to save VRAM!
# Unsloth: Double buffering enabled (parallel H2D + compute) for backward pass.
#     <div>
#
#       <progress value='1250' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1250/1250 2:10:14, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.209506</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.211276</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.124222</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.379086</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.278285</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.260314</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.182819</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.188895</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.259709</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.238710</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.299819</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.152532</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.119329</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.944594</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.029374</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.316809</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.059073</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.941344</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.795570</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.826614</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.732382</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.765910</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.662729</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.619463</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.502637</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.435279</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.315676</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.367279</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.147787</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.141332</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.119207</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.014596</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.087639</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.110312</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.094440</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.963697</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.055856</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.907547</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.004771</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.902093</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.992643</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.928076</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.908407</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.902573</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.911473</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.905165</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.900448</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.928932</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.902144</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.920204</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.884282</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.859608</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.769077</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.885415</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.832124</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.841527</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.785294</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.814733</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.881343</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.809800</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.889132</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.770174</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.753006</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.698983</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.799074</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.762759</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.724560</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.738324</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.738142</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.765129</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.701034</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.677531</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.775922</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.637564</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.667167</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.629848</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.743125</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.744513</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.717809</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.781280</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.702798</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.716139</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.677583</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.608034</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.714615</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.647701</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.683095</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.700749</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.620208</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.628972</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.641331</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.682261</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.669373</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.680503</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.674133</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.740369</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.641295</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.680369</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.662847</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.651780</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.655543</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.595238</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.693550</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.638399</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.622627</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.700651</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.644105</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.590973</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.755706</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.685339</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.640949</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.642693</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.691532</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.669042</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.635780</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.616543</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.553268</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.638643</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.653344</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.637909</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.628108</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.599774</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.633559</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.627929</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.652945</td>
#     </tr>
#     <tr>
#       <td>
# Unsloth: Restored added_tokens_decoder metadata in outputs/support_lora/checkpoint-500/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in outputs/support_lora/checkpoint-1000/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in outputs/support_lora/checkpoint-1250/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in outputs/support_lora/tokenizer_config.json.
# Training Complete. LoRA weights saved!

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	huggingface_tokenizers_cache/
# 	unsloth_compiled_cache/
# 	../huggingface_tokenizers_cache/
# 	../unsloth_compiled_cache/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
import getpass
GITHUB_USERNAME = 'hossamhamdy333'
GITHUB_TOKEN    = getpass.getpass('GitHub token: ')
REPO_NAME       = 'AI_Portfolio'

# !git config --global user.email '210591705+hossamhamdy333@users.noreply.github.com'
# !git config --global user.name 'Hossam Hamdy'
# !git remote set-url origin https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git
# !git pull origin main
# Out:
# GitHub token: ··········
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 2.54 KiB | 433.00 KiB/s, done.
# From https://github.com/hossamhamdy333/AI_Portfolio
#  * branch            main       -> FETCH_HEAD
#    dce795e..c378365  main       -> origin/main
# Updating dce795e..c378365
# Fast-forward
#  sentiment_forge/README.md | 49 +++++++++++++++++++++--------------------------
#  1 file changed, 22 insertions(+), 27 deletions(-)

# %%
# !git add .

# %%
# !git commit -m "init"
# Out:
# [main c925b80] init
#  52 files changed, 447525 insertions(+)
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3-8b-bnb-4bit/0f893e106f7de2fb60e86f48f163213ce1e2b670.lock
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3-8b-bnb-4bit/6b7e24ffc27d3786a23045df96fc0bbbe02ce9d3.lock
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3-8b-bnb-4bit/9c44d1d78fb1f530d4839937d9850f6f5621206d.lock
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3-8b-bnb-4bit/b197f72effb9d5ed16ee0f5663e11e4cfac2ba62.lock
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3-8b-bnb-4bit/d9175ecf0d6c068cb733d41a4f1b2a6611d689b8.lock
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/CACHEDIR.TAG
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/.no_exist/f20166737ba79ae1129e83194c84e2ec0013bf1b/added_tokens.json
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/.no_exist/f20166737ba79ae1129e83194c84e2ec0013bf1b/chat_template.jinja
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/.no_exist/f20166737ba79ae1129e83194c84e2ec0013bf1b/tokenizer.model
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/blobs/0f893e106f7de2fb60e86f48f163213ce1e2b670
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/blobs/6b7e24ffc27d3786a23045df96fc0bbbe02ce9d3
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/blobs/9c44d1d78fb1f530d4839937d9850f6f5621206d
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/blobs/b197f72effb9d5ed16ee0f5663e11e4cfac2ba62
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/blobs/d9175ecf0d6c068cb733d41a4f1b2a6611d689b8
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/refs/main
#  create mode 120000 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/snapshots/f20166737ba79ae1129e83194c84e2ec0013bf1b/config.json
#  create mode 120000 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/snapshots/f20166737ba79ae1129e83194c84e2ec0013bf1b/generation_config.json
#  create mode 120000 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/snapshots/f20166737ba79ae1129e83194c84e2ec0013bf1b/special_tokens_map.json
#  create mode 120000 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/snapshots/f20166737ba79ae1129e83194c84e2ec0013bf1b/tokenizer.json
#  create mode 120000 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/snapshots/f20166737ba79ae1129e83194c84e2ec0013bf1b/tokenizer_config.json
#  create mode 100644 customer_support_copilot/huggingface_tokenizers_cache/models--unsloth--llama-3-8b-bnb-4bit/trees/f20166737ba79ae1129e83194c84e2ec0013bf1b.json
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothBCOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothCPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothDPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothGKDTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothGRPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothKTOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothNashMDTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothORPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothOnlineDPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothPPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothPRMTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothRLOOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothRewardTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothSFTTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/.locks/.lock.UnslothXPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothBCOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothCPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothDPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothGKDTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothGRPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothKTOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothNashMDTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothORPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothOnlineDPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothPPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothPRMTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothRLOOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothRewardTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothSFTTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/UnslothXPOTrainer.py
#  create mode 100644 customer_support_copilot/unsloth_compiled_cache/moe_utils.py

# %%
# !git push
# Out:
# Enumerating objects: 48, done.
# Counting objects: 100% (48/48), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (43/43), done.
# Writing objects: 100% (46/46), 2.45 MiB | 3.36 MiB/s, done.
# Total 46 (delta 15), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (15/15), completed with 2 local objects.
# To https://github.com/hossamhamdy333/AI_Portfolio.git
#    c378365..c925b80  main -> main
